# %%
import pandas as pd
import json

# %%
def flatten(doc, parent_key='', sep='_'):
    items = []
    for k,v in doc.items():
        new_key = f'{parent_key}{sep}{k}' if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            for i, sub_item in enumerate(v):
                if isinstance(sub_item,dict):
                    items.extend(flatten(sub_item, f'{new_key}{sep}{i}', sep=sep).items())
                else:
                    items.append((f"{new_key}{sep}{i}", sub_item))
        else:
            items.append((new_key,v))
    return dict(items)

# %%
with open(r'D:\python_files\Bosta\data\raw\raw.json') as file:
    data = json.load(file)
data
# Out:
# {'type': 'collection',
#  'entry': [{'fullUrl': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603',
#    'resource': {'id': '2fd2f9de-0d6a-4773-b0a2-a26284aa8603',
#     'text': {'status': 'generated',
#      'div': '<div>Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>. Version identifier: abb19fb6343d94061d3cec2142ac2e3d332ac45e</div>'},
#     'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/us-core-race',
#       'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/v3/Race',
#          'code': '2106-3',
#          'display': 'White'}],
#        'text': 'race'}},
#      {'url': 'http://hl7.org/fhir/StructureDefinition/us-core-ethnicity',
#       'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/v3/Ethnicity',
#          'code': '2186-5',
#          'display': 'Nonhispanic'}],
#        'text': 'ethnicity'}},
#      {'url': 'http://standardhealthrecord.org/fhir/extensions/placeOfBirth',
#       'valueAddress': {'city': 'Peabody', 'state': 'MA'}},
#      {'url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName',
#       'valueString': 'Kira814 Sipes704'},
#      {'url': 'http://standardhealthrecord.org/fhir/extensions/fathersName',
#       'valueString': 'Allie402 Schiller837'}],
#     'identifier': [{'system': 'https://github.com/synthetichealth/synthea',
#       'value': '01000f8b-63bc-4de5-8d7b-024456f013f4'},
#      {'type': {'coding': [{'system': 'http://hl7.org/fhir/identifier-type',
#          'code': 'SB'}]},
#       'system': 'http://hl7.org/fhir/sid/us-ssn',
#       'value': '999657341'},
#      {'type': {'coding': [{'system': 'http://hl7.org/fhir/v2/0203',
#          'code': 'DL'}]},
#       'system': 'urn:oid:2.16.840.1.113883.4.3.25',
#       'value': 'S99930082'}],
#     'name': [{'use': 'official',
#       'family': 'Schiller837',
#       'given': ['Otilia827'],
#       'prefix': ['Ms.']}],
#     'telecom': [{'extension': [{'url': 'http://standardhealthrecord.org/fhir/extensions/okayToLeaveMessage',
#         'valueBoolean': True}],
#       'system': 'phone',
#       'value': '(182) 613-0657',
#       'use': 'home'}],
#     'gender': 'female',
#     'birthDate': '1960-06-03',
#     'address': [{'extension': [{'extension': [{'url': 'latitude',
#           'valueDecimal': 42.48813933232038},
#          {'url': 'longitude', 'valueDecimal': -71.34308416034564}],
#         'url': 'http://hl7.org/fhir/StructureDefinition/geolocation'}],
#       'line': ['3973 Terrance Field', 'Suite 570'],
#       'city': 'Concord',
#       'state': 'MA',
#       'postalCode': '01742'}],
#     'maritalStatus': {'coding': [{'system': 'http://hl7.org/fhir/v3/MaritalStatus',
#        'code': 'S'}]},
#     'multipleBirthBoolean': False,
#     'photo': [{'contentType': 'image/png',
#       'data': '...',
#       'title': 'Biometrics.Fingerprint'}],
#     'resourceType': 'Patient'}},
#   {'fullUrl': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499',
#    'resource': {'id': '513b2953-5a0d-4648-a694-f3a119845499',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2010-08-08T00:43:37-04:00',
#      'end': '2010-08-08T01:43:37-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:34d7fa14-2791-4180-a907-5e05db2c7653',
#    'resource': {'id': '34d7fa14-2791-4180-a907-5e05db2c7653',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:4843f457-e4f6-4bc6-8a4a-4248ab96343c',
#    'resource': {'id': '4843f457-e4f6-4bc6-8a4a-4248ab96343c',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:33fa6331-4127-4f73-9223-5ca4f09b21a7',
#    'resource': {'id': '33fa6331-4127-4f73-9223-5ca4f09b21a7',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:e76d7522-5056-406d-86a0-84b39a8fed3f',
#    'resource': {'id': 'e76d7522-5056-406d-86a0-84b39a8fed3f',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 128,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 84,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:ad8b978e-b342-4e82-a400-f73652360902',
#    'resource': {'id': 'ad8b978e-b342-4e82-a400-f73652360902',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '2093-3',
#        'display': 'Total Cholesterol'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 163,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:d4bce277-db3a-44e2-bb25-b0ecf88a639b',
#    'resource': {'id': 'd4bce277-db3a-44e2-bb25-b0ecf88a639b',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '2571-8',
#        'display': 'Triglycerides'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 149,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:e121096e-b647-4624-ac22-fc57ac16ef44',
#    'resource': {'id': 'e121096e-b647-4624-ac22-fc57ac16ef44',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Low Density Lipoprotein Cholesterol'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 70,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:4b479854-2a59-4a00-9607-8b2192ef0a0c',
#    'resource': {'id': '4b479854-2a59-4a00-9607-8b2192ef0a0c',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '2085-9',
#        'display': 'High Density Lipoprotein Cholesterol'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'valueQuantity': {'value': 63,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:a9129e78-b9e8-4fb6-8f26-250805147862',
#    'resource': {'id': 'a9129e78-b9e8-4fb6-8f26-250805147862',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '57698-3',
#        'display': 'Lipid Panel'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'effectiveDateTime': '2010-08-08T00:43:37-04:00',
#     'issued': '2010-08-08T00:43:37-04:00',
#     'performer': [{'display': 'Hospital Lab'}],
#     'result': [{'reference': 'urn:uuid:ad8b978e-b342-4e82-a400-f73652360902',
#       'display': 'Total Cholesterol'},
#      {'reference': 'urn:uuid:d4bce277-db3a-44e2-bb25-b0ecf88a639b',
#       'display': 'Triglycerides'},
#      {'reference': 'urn:uuid:e121096e-b647-4624-ac22-fc57ac16ef44',
#       'display': 'Low Density Lipoprotein Cholesterol'},
#      {'reference': 'urn:uuid:4b479854-2a59-4a00-9607-8b2192ef0a0c',
#       'display': 'High Density Lipoprotein Cholesterol'}],
#     'resourceType': 'DiagnosticReport'}},
#   {'resource': {'status': 'completed',
#     'date': '2010-08-08T00:43:37-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'resourceType': 'Immunization'}},
#   {'resource': {'status': 'active',
#     'stage': {'coding': [{'system': 'http://hl7.org/fhir/request-stage',
#        'code': 'original-order'}]},
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '834060',
#        'display': 'Penicillin V Potassium 250 MG'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'context': {'reference': 'urn:uuid:513b2953-5a0d-4648-a694-f3a119845499'},
#     'dateWritten': '1962-11-12',
#     'dosageInstruction': [{}],
#     'resourceType': 'MedicationRequest'}},
#   {'fullUrl': 'urn:uuid:001c7f52-1c73-4d93-ba83-af018c6cf554',
#    'resource': {'id': '001c7f52-1c73-4d93-ba83-af018c6cf554',
#     'status': 'finished',
#     'class': {'code': 'ambulatory'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185345009'}],
#       'text': 'Encounter for symptom'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2010-09-01T06:32:08-04:00',
#      'end': '2010-09-01T06:32:08-04:00'},
#     'reason': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '195662009',
#        'display': 'Acute viral pharyngitis (disorder)'}]},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:d2be8147-0ded-48ce-bc9d-9327b48c97aa',
#    'resource': {'id': 'd2be8147-0ded-48ce-bc9d-9327b48c97aa',
#     'clinicalStatus': 'active',
#     'verificationStatus': 'confirmed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '195662009',
#        'display': 'Acute viral pharyngitis (disorder)'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'context': {'reference': 'urn:uuid:001c7f52-1c73-4d93-ba83-af018c6cf554'},
#     'onsetDateTime': '2010-08-28T12:35:32-04:00',
#     'abatementDateTime': '2010-09-13T07:19:55-04:00',
#     'resourceType': 'Condition'}},
#   {'fullUrl': 'urn:uuid:287db715-c966-439c-a33c-4a94a1ac7cbf',
#    'resource': {'id': '287db715-c966-439c-a33c-4a94a1ac7cbf',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8331-1',
#        'display': 'Oral temperature'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:001c7f52-1c73-4d93-ba83-af018c6cf554'},
#     'effectiveDateTime': '2010-09-01T06:32:08-04:00',
#     'valueQuantity': {'value': 38,
#      'unit': 'Cel',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'Cel'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8',
#    'resource': {'id': 'ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2011-08-22T15:07:55-04:00',
#      'end': '2011-08-22T16:07:55-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:f15b19d9-fc2d-48ce-ad44-95c2233a7b1d',
#    'resource': {'id': 'f15b19d9-fc2d-48ce-ad44-95c2233a7b1d',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'effectiveDateTime': '2011-08-22T15:07:55-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:b9714cda-2f4a-4abd-89a0-f4cfeffd8dbf',
#    'resource': {'id': 'b9714cda-2f4a-4abd-89a0-f4cfeffd8dbf',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'effectiveDateTime': '2011-08-22T15:07:55-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:dfb05d93-949f-461c-a4f7-1414f83eedca',
#    'resource': {'id': 'dfb05d93-949f-461c-a4f7-1414f83eedca',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'effectiveDateTime': '2011-08-22T15:07:55-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:42fc5bbc-0cf7-423c-bdf5-b8d32678d7e4',
#    'resource': {'id': '42fc5bbc-0cf7-423c-bdf5-b8d32678d7e4',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'effectiveDateTime': '2011-08-22T15:07:55-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 102,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 81,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'resource': {'status': 'completed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '428191000124101',
#        'display': 'Documentation of current medications'}],
#      'text': 'Documentation of current medications'},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'performedDateTime': '2011-08-22T15:07:55-04:00',
#     'resourceType': 'Procedure'}},
#   {'resource': {'status': 'completed',
#     'date': '2011-08-22T15:07:55-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'resourceType': 'Immunization'}},
#   {'resource': {'status': 'completed',
#     'date': '2011-08-22T15:07:55-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '113',
#        'display': 'Td (adult) preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:ed135d0f-81f7-4a97-9c5e-46dcacf7e0e8'},
#     'resourceType': 'Immunization'}},
#   {'fullUrl': 'urn:uuid:4fb0816e-9e24-44c8-acca-05d8ed2f5ed5',
#    'resource': {'id': '4fb0816e-9e24-44c8-acca-05d8ed2f5ed5',
#     'status': 'finished',
#     'class': {'code': 'ambulatory'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185345009'}],
#       'text': 'Encounter for symptom'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2012-05-29T21:14:19-04:00',
#      'end': '2012-05-29T21:14:19-04:00'},
#     'reason': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '444814009',
#        'display': 'Viral sinusitis (disorder)'}]},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:e9b7e1e0-8fa2-4411-bcdb-6a2f4d701cfc',
#    'resource': {'id': 'e9b7e1e0-8fa2-4411-bcdb-6a2f4d701cfc',
#     'clinicalStatus': 'active',
#     'verificationStatus': 'confirmed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '444814009',
#        'display': 'Viral sinusitis (disorder)'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'context': {'reference': 'urn:uuid:4fb0816e-9e24-44c8-acca-05d8ed2f5ed5'},
#     'onsetDateTime': '2012-05-21T21:16:21-04:00',
#     'abatementDateTime': '2012-06-12T06:33:02-04:00',
#     'resourceType': 'Condition'}},
#   {'resource': {'status': 'stopped',
#     'stage': {'coding': [{'system': 'http://hl7.org/fhir/request-stage',
#        'code': 'original-order'}]},
#     'medicationCodeableConcept': {'coding': [{'system': 'http://www.nlm.nih.gov/research/umls/rxnorm',
#        'code': '824184',
#        'display': ' Amoxicillin 250 MG / Clavulanate 125 MG [Augmentin]'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'context': {'reference': 'urn:uuid:4fb0816e-9e24-44c8-acca-05d8ed2f5ed5'},
#     'dateWritten': '2012-05-29',
#     'reasonReference': [{'reference': 'urn:uuid:e9b7e1e0-8fa2-4411-bcdb-6a2f4d701cfc'}],
#     'dosageInstruction': [{}],
#     'resourceType': 'MedicationRequest'}},
#   {'fullUrl': 'urn:uuid:f080774c-4f52-41d8-8351-2e8b4e86f1ab',
#    'resource': {'id': 'f080774c-4f52-41d8-8351-2e8b4e86f1ab',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2012-07-20T23:18:50-04:00',
#      'end': '2012-07-21T00:18:50-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:cfa81f0c-2669-461e-84d1-93a324d92eba',
#    'resource': {'id': 'cfa81f0c-2669-461e-84d1-93a324d92eba',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:f080774c-4f52-41d8-8351-2e8b4e86f1ab'},
#     'effectiveDateTime': '2012-07-20T23:18:50-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:41202d73-bb19-4ee7-996b-201a65f90f72',
#    'resource': {'id': '41202d73-bb19-4ee7-996b-201a65f90f72',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:f080774c-4f52-41d8-8351-2e8b4e86f1ab'},
#     'effectiveDateTime': '2012-07-20T23:18:50-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:c0890927-08b6-45a9-8cf3-2977b640e1f7',
#    'resource': {'id': 'c0890927-08b6-45a9-8cf3-2977b640e1f7',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:f080774c-4f52-41d8-8351-2e8b4e86f1ab'},
#     'effectiveDateTime': '2012-07-20T23:18:50-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:022c7828-fa36-4dfd-a779-4207a9ba14b6',
#    'resource': {'id': '022c7828-fa36-4dfd-a779-4207a9ba14b6',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:f080774c-4f52-41d8-8351-2e8b4e86f1ab'},
#     'effectiveDateTime': '2012-07-20T23:18:50-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 117,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 71,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'resource': {'status': 'completed',
#     'date': '2012-07-20T23:18:50-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:f080774c-4f52-41d8-8351-2e8b4e86f1ab'},
#     'resourceType': 'Immunization'}},
#   {'fullUrl': 'urn:uuid:8de39854-6007-4688-b7f9-8d51bb01f39a',
#    'resource': {'id': '8de39854-6007-4688-b7f9-8d51bb01f39a',
#     'status': 'finished',
#     'class': {'code': 'ambulatory'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185345009'}],
#       'text': 'Encounter for symptom'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2013-04-16T07:13:03-04:00',
#      'end': '2013-04-16T07:13:03-04:00'},
#     'reason': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '195662009',
#        'display': 'Acute viral pharyngitis (disorder)'}]},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:df918c32-c7cc-4da4-9d31-ba76380dddb1',
#    'resource': {'id': 'df918c32-c7cc-4da4-9d31-ba76380dddb1',
#     'clinicalStatus': 'active',
#     'verificationStatus': 'confirmed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '195662009',
#        'display': 'Acute viral pharyngitis (disorder)'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'context': {'reference': 'urn:uuid:8de39854-6007-4688-b7f9-8d51bb01f39a'},
#     'onsetDateTime': '2013-04-13T07:19:55-04:00',
#     'abatementDateTime': '2013-04-25T22:13:46-04:00',
#     'resourceType': 'Condition'}},
#   {'fullUrl': 'urn:uuid:45f6e778-acac-4561-bfb4-ea07074d257e',
#    'resource': {'id': '45f6e778-acac-4561-bfb4-ea07074d257e',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8331-1',
#        'display': 'Oral temperature'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:8de39854-6007-4688-b7f9-8d51bb01f39a'},
#     'effectiveDateTime': '2013-04-16T07:13:03-04:00',
#     'valueQuantity': {'value': 37,
#      'unit': 'Cel',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'Cel'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:36bdae09-70d8-4d5f-9251-70dcc232690b',
#    'resource': {'id': '36bdae09-70d8-4d5f-9251-70dcc232690b',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2013-07-28T19:48:20-04:00',
#      'end': '2013-07-28T20:48:20-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:ac4cf08f-85e4-44ca-bc05-7f38f597ddfd',
#    'resource': {'id': 'ac4cf08f-85e4-44ca-bc05-7f38f597ddfd',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:36bdae09-70d8-4d5f-9251-70dcc232690b'},
#     'effectiveDateTime': '2013-07-28T19:48:20-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:41f9a80a-bc05-4e06-abb7-fd45c6248ffb',
#    'resource': {'id': '41f9a80a-bc05-4e06-abb7-fd45c6248ffb',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:36bdae09-70d8-4d5f-9251-70dcc232690b'},
#     'effectiveDateTime': '2013-07-28T19:48:20-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:c951db76-2f23-4f4f-b8e0-d597d1941c4e',
#    'resource': {'id': 'c951db76-2f23-4f4f-b8e0-d597d1941c4e',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:36bdae09-70d8-4d5f-9251-70dcc232690b'},
#     'effectiveDateTime': '2013-07-28T19:48:20-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:5e068a8d-cb1f-4000-af97-aca0954391d4',
#    'resource': {'id': '5e068a8d-cb1f-4000-af97-aca0954391d4',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:36bdae09-70d8-4d5f-9251-70dcc232690b'},
#     'effectiveDateTime': '2013-07-28T19:48:20-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 106,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 89,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'resource': {'status': 'completed',
#     'date': '2013-07-28T19:48:20-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:36bdae09-70d8-4d5f-9251-70dcc232690b'},
#     'resourceType': 'Immunization'}},
#   {'fullUrl': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052',
#    'resource': {'id': '663fd7ea-7c2d-48bc-a3df-22f417da2052',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2014-08-11T22:25:33-04:00',
#      'end': '2014-08-11T23:25:33-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:62c9a1fd-50f0-4ece-a592-2eb03c4c96da',
#    'resource': {'id': '62c9a1fd-50f0-4ece-a592-2eb03c4c96da',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:10bf1b10-3228-47c8-855e-34ea020de79d',
#    'resource': {'id': '10bf1b10-3228-47c8-855e-34ea020de79d',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:dc8d9687-42bc-4cfc-9b85-f8a588490234',
#    'resource': {'id': 'dc8d9687-42bc-4cfc-9b85-f8a588490234',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:8d1ff951-c2d0-4e4d-be24-918cd23f67bc',
#    'resource': {'id': '8d1ff951-c2d0-4e4d-be24-918cd23f67bc',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 104,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 78,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:c1822385-afb2-46f4-b615-61070940e832',
#    'resource': {'id': 'c1822385-afb2-46f4-b615-61070940e832',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '2093-3',
#        'display': 'Total Cholesterol'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 175,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:bf2faae7-d1bc-41d5-8b26-115c5dfd9559',
#    'resource': {'id': 'bf2faae7-d1bc-41d5-8b26-115c5dfd9559',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '2571-8',
#        'display': 'Triglycerides'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 132,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:11b34edd-ab1c-47e3-af49-38eaa5bd742c',
#    'resource': {'id': '11b34edd-ab1c-47e3-af49-38eaa5bd742c',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Low Density Lipoprotein Cholesterol'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 86,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:b9d47577-4600-4ca2-b09f-5a682a97a8ed',
#    'resource': {'id': 'b9d47577-4600-4ca2-b09f-5a682a97a8ed',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '2085-9',
#        'display': 'High Density Lipoprotein Cholesterol'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'valueQuantity': {'value': 62,
#      'unit': 'mg/dL',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'mg/dL'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:08f2db2a-123e-46eb-8215-9ce2ccc7e514',
#    'resource': {'id': '08f2db2a-123e-46eb-8215-9ce2ccc7e514',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '57698-3',
#        'display': 'Lipid Panel'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'effectiveDateTime': '2014-08-11T22:25:33-04:00',
#     'issued': '2014-08-11T22:25:33-04:00',
#     'performer': [{'display': 'Hospital Lab'}],
#     'result': [{'reference': 'urn:uuid:c1822385-afb2-46f4-b615-61070940e832',
#       'display': 'Total Cholesterol'},
#      {'reference': 'urn:uuid:bf2faae7-d1bc-41d5-8b26-115c5dfd9559',
#       'display': 'Triglycerides'},
#      {'reference': 'urn:uuid:11b34edd-ab1c-47e3-af49-38eaa5bd742c',
#       'display': 'Low Density Lipoprotein Cholesterol'},
#      {'reference': 'urn:uuid:b9d47577-4600-4ca2-b09f-5a682a97a8ed',
#       'display': 'High Density Lipoprotein Cholesterol'}],
#     'resourceType': 'DiagnosticReport'}},
#   {'resource': {'status': 'completed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '428191000124101',
#        'display': 'Documentation of current medications'}],
#      'text': 'Documentation of current medications'},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'performedDateTime': '2014-08-11T22:25:33-04:00',
#     'resourceType': 'Procedure'}},
#   {'resource': {'status': 'completed',
#     'date': '2014-08-11T22:25:33-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:663fd7ea-7c2d-48bc-a3df-22f417da2052'},
#     'resourceType': 'Immunization'}},
#   {'fullUrl': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54',
#    'resource': {'id': '8b60b11b-00c0-4b32-bea5-0fa4192ada54',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2015-07-19T03:25:12-04:00',
#      'end': '2015-07-19T04:25:12-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:b813e697-a5bc-4cd9-9f1c-1adffffac5ec',
#    'resource': {'id': 'b813e697-a5bc-4cd9-9f1c-1adffffac5ec',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54'},
#     'effectiveDateTime': '2015-07-19T03:25:12-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:33425bf6-50f2-42dd-b93d-57ae61c03b70',
#    'resource': {'id': '33425bf6-50f2-42dd-b93d-57ae61c03b70',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54'},
#     'effectiveDateTime': '2015-07-19T03:25:12-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:3e2d4529-af07-4269-b28d-286bc6dfd81b',
#    'resource': {'id': '3e2d4529-af07-4269-b28d-286bc6dfd81b',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54'},
#     'effectiveDateTime': '2015-07-19T03:25:12-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:eab451fe-c55c-40cd-a5ed-5254cd838757',
#    'resource': {'id': 'eab451fe-c55c-40cd-a5ed-5254cd838757',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54'},
#     'effectiveDateTime': '2015-07-19T03:25:12-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 104,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 83,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'resource': {'status': 'completed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '428191000124101',
#        'display': 'Documentation of current medications'}],
#      'text': 'Documentation of current medications'},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54'},
#     'performedDateTime': '2015-07-19T03:25:12-04:00',
#     'resourceType': 'Procedure'}},
#   {'resource': {'status': 'completed',
#     'date': '2015-07-19T03:25:12-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:8b60b11b-00c0-4b32-bea5-0fa4192ada54'},
#     'resourceType': 'Immunization'}},
#   {'fullUrl': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa',
#    'resource': {'id': '178b34fc-3db4-4bff-ad10-9fc5a951ebfa',
#     'status': 'finished',
#     'class': {'code': 'outpatient'},
#     'type': [{'coding': [{'system': 'http://snomed.info/sct',
#         'code': '185349003'}],
#       'text': 'Outpatient Encounter'}],
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'period': {'start': '2016-07-06T23:34:21-04:00',
#      'end': '2016-07-07T00:34:21-04:00'},
#     'resourceType': 'Encounter'}},
#   {'fullUrl': 'urn:uuid:6018ac27-5f58-4105-842c-e436c48119fa',
#    'resource': {'id': '6018ac27-5f58-4105-842c-e436c48119fa',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '8302-2',
#        'display': 'Body Height'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa'},
#     'effectiveDateTime': '2016-07-06T23:34:21-04:00',
#     'valueQuantity': {'value': 172.59517038772603,
#      'unit': 'cm',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'cm'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:c4095b5d-25fd-433d-9a22-9adec1a0200b',
#    'resource': {'id': 'c4095b5d-25fd-433d-9a22-9adec1a0200b',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '29463-7',
#        'display': 'Body Weight'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa'},
#     'effectiveDateTime': '2016-07-06T23:34:21-04:00',
#     'valueQuantity': {'value': 91.50333554275414,
#      'unit': 'kg',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:d90370a2-56c8-45d1-871a-9b116da31386',
#    'resource': {'id': 'd90370a2-56c8-45d1-871a-9b116da31386',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '39156-5',
#        'display': 'Body Mass Index'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa'},
#     'effectiveDateTime': '2016-07-06T23:34:21-04:00',
#     'valueQuantity': {'value': 30.71706011010097,
#      'unit': 'kg/m2',
#      'system': 'http://unitsofmeasure.org/',
#      'code': 'kg/m2'},
#     'resourceType': 'Observation'}},
#   {'fullUrl': 'urn:uuid:09f4a54f-5ec8-4641-aefd-d62d2e565d45',
#    'resource': {'id': '09f4a54f-5ec8-4641-aefd-d62d2e565d45',
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55284-4',
#        'display': 'Blood Pressure'}]},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa'},
#     'effectiveDateTime': '2016-07-06T23:34:21-04:00',
#     'component': [{'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8480-6',
#          'display': 'Systolic Blood Pressure'}]},
#       'valueQuantity': {'value': 135,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}},
#      {'code': {'coding': [{'system': 'http://loinc.org',
#          'code': '8462-4',
#          'display': 'Diastolic Blood Pressure'}]},
#       'valueQuantity': {'value': 77,
#        'unit': 'mmHg',
#        'system': 'http://unitsofmeasure.org/',
#        'code': 'mmHg'}}],
#     'resourceType': 'Observation'}},
#   {'resource': {'status': 'completed',
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '428191000124101',
#        'display': 'Documentation of current medications'}],
#      'text': 'Documentation of current medications'},
#     'subject': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'encounter': {'reference': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa'},
#     'performedDateTime': '2016-07-06T23:34:21-04:00',
#     'resourceType': 'Procedure'}},
#   {'resource': {'status': 'completed',
#     'date': '2016-07-06T23:34:21-04:00',
#     'vaccineCode': {'coding': [{'system': 'http://hl7.org/fhir/sid/cvx',
#        'code': '140',
#        'display': 'Influenza, seasonal, injectable, preservative free'}]},
#     'patient': {'reference': 'urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603'},
#     'wasNotGiven': False,
#     'primarySource': True,
#     'encounter': {'reference': 'urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa'},
#     'resourceType': 'Immunization'}}],
#  'resourceType': 'Bundle'}

# %%
jdata = flatten(data)
# df = pd.DataFrame(jdata)
jdata
df = pd.DataFrame([jdata])
df
# Out:
#          type                                entry_0_fullUrl  \
# 0  collection  urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603
#
#                     entry_0_resource_id entry_0_resource_text_status  \
# 0  2fd2f9de-0d6a-4773-b0a2-a26284aa8603                    generated
#
#                            entry_0_resource_text_div  \
# 0  <div>Generated by <a href="https://github.com/...
#
#                     entry_0_resource_extension_0_url  \
# 0  http://hl7.org/fhir/StructureDefinition/us-cor...
#
#   entry_0_resource_extension_0_valueCodeableConcept_coding_0_system  \
# 0                        http://hl7.org/fhir/v3/Race
#
#   entry_0_resource_extension_0_valueCodeableConcept_coding_0_code  \
# 0                                             2106-3
#
#   entry_0_resource_extension_0_valueCodeableConcept_coding_0_display  \
# 0                                              White
#
#   entry_0_resource_extension_0_valueCodeableConcept_text  ...  \
# 0                                               race      ...
#
#       entry_67_resource_date entry_67_resource_vaccineCode_coding_0_system  \
# 0  2016-07-06T23:34:21-04:00                   http://hl7.org/fhir/sid/cvx
#
#   entry_67_resource_vaccineCode_coding_0_code  \
# 0                                         140
#
#       entry_67_resource_vaccineCode_coding_0_display  \
# 0  Influenza, seasonal, injectable, preservative ...
#
#              entry_67_resource_patient_reference  \
# 0  urn:uuid:2fd2f9de-0d6a-4773-b0a2-a26284aa8603
#
#   entry_67_resource_wasNotGiven entry_67_resource_primarySource  \
# 0                         False                            True
#
#            entry_67_resource_encounter_reference  \
# 0  urn:uuid:178b34fc-3db4-4bff-ad10-9fc5a951ebfa
#
#   entry_67_resource_resourceType resourceType
# 0                   Immunization       Bundle
#
# [1 rows x 995 columns]
